# %%
# !git clone 'https://github.com/Vlad188-1/Hack_2024.git'
# Out:
# Cloning into 'Hack_2024'...

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\encodee\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\encodee\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\encodee\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in _fp_read
#     data = self._fp.read(chunk_amt)
#   File "C:\Users\encodee\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#   File "C:\Users\encodee\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 462, in read
#     n = self.readinto(b)
# ...

# %%
# !python3 main.py
# Out:
# Python
